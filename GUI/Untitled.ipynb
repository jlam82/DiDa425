# %%
import os
import pygame
import sys

# ————— Setup —————
pygame.init()
FPS = 60
clock = pygame.time.Clock()

# Load your new tile
BASE_DIR = os.path.dirname(__file__)  # if you run from the project root
tile_path = os.path.join(BASE_DIR, 'Floor_14_Tile.png')
tile = pygame.image.load(tile_path).convert_alpha()
TILE_W, TILE_H = tile.get_width(), tile.get_height()

# Define room size in tiles
ROOM_TILES_X = 12
ROOM_TILES_Y = 9

# Compute window size
WIDTH, HEIGHT = TILE_W * ROOM_TILES_X, TILE_H * ROOM_TILES_Y
screen = pygame.display.set_mode((WIDTH, HEIGHT))
pygame.display.set_caption("Tiled Room (Floor 14)")

# Wall settings
WALL_THICKNESS = 24
WALL_COLOR = (60, 60, 60)

# ————— Drawing functions —————
def draw_floor():
    for y in range(0, HEIGHT, TILE_H):
        for x in range(0, WIDTH, TILE_W):
            screen.blit(tile, (x, y))

def draw_walls():
    # top
    pygame.draw.rect(screen, WALL_COLOR, (0, 0, WIDTH, WALL_THICKNESS))
    # bottom
    pygame.draw.rect(screen, WALL_COLOR, (0, HEIGHT - WALL_THICKNESS, WIDTH, WALL_THICKNESS))
    # left
    pygame.draw.rect(screen, WALL_COLOR, (0, 0, WALL_THICKNESS, HEIGHT))
    # right
    pygame.draw.rect(screen, WALL_COLOR, (WIDTH - WALL_THICKNESS, 0, WALL_THICKNESS, HEIGHT))

# ————— Main loop —————
def main():
    while True:
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                pygame.quit()
                sys.exit()

        draw_floor()
        draw_walls()

        pygame.display.flip()
        clock.tick(FPS)

if __name__ == "__main__":
    main()
# Out:
# pygame-ce 2.5.3 (SDL 2.30.12, Python 3.11.4)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 11
#       8 clock = pygame.time.Clock()
#      10 # Load your new tile
# ---> 11 BASE_DIR = os.path.dirname(__file__)  # if you run from the project root
#      12 tile_path = os.path.join(BASE_DIR, 'Floor_14_Tile.png')
#      13 tile = pygame.image.load(tile_path).convert_alpha()
#
# NameError: name '__file__' is not defined

# %%
import os
import pygame
import sys

# ————— Setup —————
pygame.init()
FPS = 60
clock = pygame.time.Clock()

# — Determine your project root just like in your screenshot —
# If this is run as a script, __file__ will be defined and we grab its folder.
# Otherwise (e.g. notebook / REPL), fall back to the current working dir.
try:
    BASE_DIR = os.path.dirname(os.path.abspath(__file__))
except NameError:
    BASE_DIR = os.getcwd()

# Load the tile sitting next to main.py, just like in your directory listing
tile_path = os.path.join(BASE_DIR, 'Floor_14_Tile.png')
tile = pygame.image.load(tile_path).convert_alpha()
TILE_W, TILE_H = tile.get_width(), tile.get_height()

# — Room dimensions (in tiles) — tweak as you like
ROOM_TILES_X, ROOM_TILES_Y = 12, 9

# — Window size — matches the screenshot’s project layout
WIDTH, HEIGHT = TILE_W * ROOM_TILES_X, TILE_H * ROOM_TILES_Y
screen = pygame.display.set_mode((WIDTH, HEIGHT))
pygame.display.set_caption("Tiled Room (Floor_14_Tile)")

# — Optional walls around the room —
WALL_THICKNESS = 24
WALL_COLOR = (60, 60, 60)

def draw_floor():
    for y in range(0, HEIGHT, TILE_H):
        for x in range(0, WIDTH, TILE_W):
            screen.blit(tile, (x, y))

def draw_walls():
    pygame.draw.rect(screen, WALL_COLOR, (0, 0, WIDTH, WALL_THICKNESS))                   # top
    pygame.draw.rect(screen, WALL_COLOR, (0, HEIGHT - WALL_THICKNESS, WIDTH, WALL_THICKNESS))  # bottom
    pygame.draw.rect(screen, WALL_COLOR, (0, 0, WALL_THICKNESS, HEIGHT))                  # left
    pygame.draw.rect(screen, WALL_COLOR, (WIDTH - WALL_THICKNESS, 0, WALL_THICKNESS, HEIGHT))  # right

def main():
    while True:
        for evt in pygame.event.get():
            if evt.type == pygame.QUIT:
                pygame.quit()
                sys.exit()

        draw_floor()
        draw_walls()
        pygame.display.flip()
        clock.tick(FPS)

if __name__ == '__main__':
    main()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[2], line 20
#      18 # Load the tile sitting next to main.py, just like in your directory listing
#      19 tile_path = os.path.join(BASE_DIR, 'Floor_14_Tile.png')
# ---> 20 tile = pygame.image.load(tile_path).convert_alpha()
#      21 TILE_W, TILE_H = tile.get_width(), tile.get_height()
#      23 # — Room dimensions (in tiles) — tweak as you like
#
# error: No convert format has been set, try display.set_mode() or Window.get_surface().

# %%
import os
import pygame
import sys

# ————— Setup —————
pygame.init()
FPS = 60
clock = pygame.time.Clock()

# — Determine your project root like in your screenshot —
try:
    BASE_DIR = os.path.dirname(os.path.abspath(__file__))
except NameError:
    BASE_DIR = os.getcwd()

# — Load raw tile (no convert) so we can get dimensions first —
tile_path = os.path.join(BASE_DIR, 'Floor_14_Tile.png')
raw_tile = pygame.image.load(tile_path)   # <-- no convert_alpha here
TILE_W, TILE_H = raw_tile.get_width(), raw_tile.get_height()

# — Room dimensions (in tiles) — tweak as you like —
ROOM_TILES_X, ROOM_TILES_Y = 12, 9

# — Compute window size and open display —
WIDTH, HEIGHT = TILE_W * ROOM_TILES_X, TILE_H * ROOM_TILES_Y
screen = pygame.display.set_mode((WIDTH, HEIGHT))
pygame.display.set_caption("Tiled Room (Floor_14_Tile)")

# — Now that display exists, convert for fastest blits with alpha —
tile = raw_tile.convert_alpha()

# — Optional walls around the room —
WALL_THICKNESS = 24
WALL_COLOR = (60, 60, 60)

def draw_floor():
    for y in range(0, HEIGHT, TILE_H):
        for x in range(0, WIDTH, TILE_W):
            screen.blit(tile, (x, y))

def draw_walls():
    pygame.draw.rect(screen, WALL_COLOR, (0, 0, WIDTH, WALL_THICKNESS))                        # top
    pygame.draw.rect(screen, WALL_COLOR, (0, HEIGHT - WALL_THICKNESS, WIDTH, WALL_THICKNESS))  # bottom
    pygame.draw.rect(screen, WALL_COLOR, (0, 0, WALL_THICKNESS, HEIGHT))                       # left
    pygame.draw.rect(screen, WALL_COLOR, (WIDTH - WALL_THICKNESS, 0, WALL_THICKNESS, HEIGHT))  # right

def main():
    while True:
        for evt in pygame.event.get():
            if evt.type == pygame.QUIT:
                pygame.quit()
                sys.exit()

        draw_floor()
        draw_walls()
        pygame.display.flip()
        clock.tick(FPS)

if __name__ == '__main__':
    main()
